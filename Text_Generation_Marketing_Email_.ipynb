# %% [markdown]
# # Text Generation Marketing Email
# This notebook demonstrates how to use Horizon AI to generate marketing emails.

# %% [markdown]
# ## Step 1: Create a Horizon account
# Create an account at [Horizon's website](https://www.gethorizon.ai/). Complete the email verification step!

# %% [markdown]
# ## Step 2: Get your Horizon API key

# %%
# Install the Horizon Python SDK
# %pip install horizonai

# %%
# Get your Horizon API key, skip if you already have a key to use Make sure to keep this safe!
# !horizonai user api-key

# %%
import horizonai

email = input("Enter your email address: ")
password = input("Enter your password: ")

api_key = horizonai.user.api_key(email, password)

print(api_key)
